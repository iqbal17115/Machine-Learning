# %%
import matplotlib.pyplot as plt

ages = [20, 50, 34, 23, 54, 32, 89, 100, 1, 81, 54, 61, 78, 90, 65]
range = (0,100)
bins = 10

plt.hist(ages, bins, range, color="green", histtype="bar", rwidth=0.7)
plt.xlabel('Ages')
plt.ylabel('Bins')
plt.title("Histogram Plot")

plt.show()
